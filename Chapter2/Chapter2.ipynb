# %%
![title](img/picture.png)
# Out:
# /bin/sh: -c: line 0: syntax error near unexpected token `img/picture.png'
# /bin/sh: -c: line 0: `[title](img/picture.png)'

# %% [markdown]
# Problem 1:

# %%
# %matplotlib notebook
import math
import numpy as np
import matplotlib.pyplot as plt
N = 5
a = [(2*math.pi*math.sin(2*math.pi*n) + math.cos(2*math.pi*n) - 1)/(2*(math.pi**2)*n**2) for n in range(1,N+1)]
b = [(math.sin(2*math.pi*n) - 2*math.pi*n*math.cos(2*math.pi*n))/(2*(math.pi**2)*n**2) for n in range(1,N+1)]

def fourier(x):
    a_0 = 1
    y = a_0/2 + sum([a[n-1]*math.cos(2*math.pi*n*x) + b[n-1]*math.sin(2*math.pi*n*x) for n in range(1,N+1)])
    return y


X = np.linspace(0,1,1000)
Y = [fourier(x) for x in X]
plt.scatter(X,Y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Problem 2:

# %%
import math
B=4000
print("If the highest frequency is: ", B, "Hz")
print("Sufficient sample rate is: ", 1/(2*B))
print("Data rate is: ", 2*B ," at two levels")

print("30dB is a Signal to noise ratio of 1000")
print("maximum bits per second is:", B*math.log(1 + 1000, 2))
# Out:
# If the highest frequency is:  4000 Hz
# Sufficient sample rate is:  0.000125
# Data rate is:  8000  at two levels
# 30dB is a Signal to noise ratio of 1000
# maximum bits per second is: 39868.905035343974

# %% [markdown]
# Problem 3:

# %% [markdown]
# 6000Hz channel means a 12,000 sameples per second is nessisary and sufficient to capture all information. There are 2 bits per sample, so this means 24kbs/s.
